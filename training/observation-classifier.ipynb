# %%
#hide
! [ -e /content ] && pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
from fastbook import *
from fastai.tabular.all import *
import pandas as pd
import numpy as np
from torch.nn.functional import nll_loss,log_softmax

from sklearn import preprocessing
from functools import partial
import copy

# %%
file = "dbs/training/training-data-v0-3.csv"
obs = pd.read_csv(file)
obs = obs.loc[~(obs.imgid > 1)]
data = obs[['kg', 'elu_class1', 'elu_class2', 'elu_class3', 'species', 'normalized_month', 'season']].copy()
data
# Out:
#           kg          elu_class1                      elu_class2  \
# 0         26     Cool Wet Plains      Carbonate Sedimentary Rock
# 1         26      Cold Wet Hills      Carbonate Sedimentary Rock
# 2         27      Cold Wet Hills                Metamorphic Rock
# 3         26     Cold Wet Plains                Acidic Plutonics
# 4         26     Cold Wet Plains                Acidic Plutonics
# ...       ..                 ...                             ...
# 12087603  29  Cold Wet Mountains          Mixed Sedimentary Rock
# 12087604  19  Cold Wet Mountains  Non-Carbonate Sedimentary Rock
# 12087605  19  Cold Wet Mountains  Non-Carbonate Sedimentary Rock
# 12087606  19  Cold Wet Mountains  Non-Carbonate Sedimentary Rock
# 12087607  19  Cold Wet Mountains  Non-Carbonate Sedimentary Rock
#
#                                   elu_class3                        species  \
# 0                    Mostly Deciduous Forest             Usnea subfloridana
# 1                    Mostly Deciduous Forest              Trametes ochracea
# 2         Mostly Needleleaf/Evergreen Forest            Hertelidea botryosa
# 3                            Mostly Cropland  Phellinidium ferrugineofuscum
# 4                            Mostly Cropland               Lecania naegelii
# ...                                      ...                            ...
# 12087603                   Sparse Vegetation                 Cladonia mitis
# 12087604  Swampy or Often Flooded Vegetation           Cladonia rangiferina
# 12087605  Swampy or Often Flooded Vegetation         Nephromopsis cucullata
# 12087606  Swampy or Often Flooded Vegetation             Cladonia stellaris
# 12087607  Swampy or Often Flooded Vegetation             Cladonia stellaris
#
#           normalized_month  season
# 0                        6  summer
# 1                        1  winter
# 2                        6  summer
# 3                        4  spring
# 4                       10  autumn
# ...                    ...     ...
# 12087603                 7  summer
# 12087604                 7  summer
# 12087605                 7  summer
# 12087606                 7  summer
# 12087607                 7  summer
#
# [11274565 rows x 7 columns]

# %%
obs
# Out:
#               gbifid           _family         genus  \
# 0         1431462551      Parmeliaceae         Usnea
# 1         1438086806      Polyporaceae      Trametes
# 2         1669971044   Stereocaulaceae    Hertelidea
# 3         2270949504  Hymenochaetaceae  Phellinidium
# 4         2271059142      Ramalinaceae       Lecania
# ...              ...               ...           ...
# 12087603  3750486160      Cladoniaceae      Cladonia
# 12087604  3750486210      Cladoniaceae      Cladonia
# 12087605  3750486608      Parmeliaceae  Nephromopsis
# 12087606  3750486848      Cladoniaceae      Cladonia
# 12087607  3750486945      Cladoniaceae      Cladonia
#
#                                 species  eventyear  eventmonth  eventday  \
# 0                    Usnea subfloridana       2016           5        31
# 1                     Trametes ochracea       2014          12         7
# 2                   Hertelidea botryosa       2012           5        21
# 3         Phellinidium ferrugineofuscum       2019           3         2
# 4                      Lecania naegelii       2018           9        12
# ...                                 ...        ...         ...       ...
# 12087603                 Cladonia mitis       2006           6        27
# 12087604           Cladonia rangiferina       2006           6        26
# 12087605         Nephromopsis cucullata       2006           6        26
# 12087606             Cladonia stellaris       2006           6        26
# 12087607             Cladonia stellaris       2006           6        26
#
#                     eventdate  decimallatitude  decimallongitude  kg  elu  \
# 0         2016-05-31 00:00:00        56.218360         16.416320  26  810
# 1         2014-12-07 00:00:00        58.448580         13.701640  26  372
# 2         2012-05-21 00:00:00        59.551380         12.236730  27  301
# 3         2019-03-02 00:00:00        59.845890         17.567560  26  451
# 4         2018-09-12 00:00:00        59.262680         15.548110  26  451
# ...                       ...              ...               ...  ..  ...
# 12087603  2006-06-27 00:00:00        59.988337       -150.566099  29   14
# 12087604  2006-06-26 00:00:00        60.318215       -150.361411  19  141
# 12087605  2006-06-26 00:00:00        60.318215       -150.361411  19  141
# 12087606  2006-06-26 00:00:00        60.318215       -150.361411  19  141
# 12087607  2006-06-26 00:00:00        60.318215       -150.361411  19  141
#
#                   elu_class1                      elu_class2  \
# 0            Cool Wet Plains      Carbonate Sedimentary Rock
# 1             Cold Wet Hills      Carbonate Sedimentary Rock
# 2             Cold Wet Hills                Metamorphic Rock
# 3            Cold Wet Plains                Acidic Plutonics
# 4            Cold Wet Plains                Acidic Plutonics
# ...                      ...                             ...
# 12087603  Cold Wet Mountains          Mixed Sedimentary Rock
# 12087604  Cold Wet Mountains  Non-Carbonate Sedimentary Rock
# 12087605  Cold Wet Mountains  Non-Carbonate Sedimentary Rock
# 12087606  Cold Wet Mountains  Non-Carbonate Sedimentary Rock
# 12087607  Cold Wet Mountains  Non-Carbonate Sedimentary Rock
#
#                                   elu_class3  normalized_month  imgid  season
# 0                    Mostly Deciduous Forest                 6    NaN  summer
# 1                    Mostly Deciduous Forest                 1    NaN  winter
# 2         Mostly Needleleaf/Evergreen Forest                 6    NaN  summer
# 3                            Mostly Cropland                 4    NaN  spring
# 4                            Mostly Cropland                10    NaN  autumn
# ...                                      ...               ...    ...     ...
# 12087603                   Sparse Vegetation                 7    NaN  summer
# 12087604  Swampy or Often Flooded Vegetation                 7    NaN  summer
# 12087605  Swampy or Often Flooded Vegetation                 7    NaN  summer
# 12087606  Swampy or Often Flooded Vegetation                 7    NaN  summer
# 12087607  Swampy or Often Flooded Vegetation                 7    NaN  summer
#
# [11274565 rows x 18 columns]

# %%
family_map = {species:family for (species,_,family) in obs.groupby(by=["species","genus","_family"]).indices.keys()}
family_list = list(family_map.values())
fle = preprocessing.LabelEncoder()
family_targets = torch.tensor(fle.fit_transform(family_list), device='cuda:0')
family_dims = family_targets.max().int().item() + 1

genus_map = {species:genus for (species,genus,_) in obs.groupby(by=["species","genus","_family"]).indices.keys()}
genus_list = list(genus_map.values())
gle = preprocessing.LabelEncoder()
genus_targets = torch.tensor(gle.fit_transform(genus_list), device='cuda:0')
genus_dims = genus_targets.max().int().item() + 1

# %%
splits = RandomSplitter(valid_pct=0.2, seed=42)(range_of(data))
to = TabularPandas(data, procs=[Categorify, FillMissing,Normalize],
                   cat_names = ['kg', 'elu_class1', 'elu_class2', 'elu_class3', 'normalized_month', 'season'],
                   # cont_names = ['decimallatitude', 'decimallongitude'],
                   y_names='species',
                   splits=splits)
to
# Out:
#          kg  elu_class1  elu_class2  elu_class3  species  normalized_month  \
# 3729261  15          22           3           2      773                11
# 4656730  26          11           5           5     1786                11
# 5097181  27           9           1           3     1011                 9
# 7794618  15          10           8           2     1219                11
# 1518646  27          10           5           5      620                 6
# ...      ..         ...         ...         ...      ...               ...
# 4523706  26          11           5           5      830                 5
# 4333343  26           2           0           0     1827                 1
# 4447886  15          11          12           4      807                10
# 2619258  27           9           5           5     1603                11
# 4252802  27          10           3           1      769                10
#
#          season
# 3729261       1
# 4656730       1
# 5097181       1
# 7794618       1
# 1518646       3
# ...         ...
# 4523706       2
# 4333343       4
# 4447886       1
# 2619258       1
# 4252802       1
#
# [11274565 rows x 7 columns]

# %%
def accuracy_species(inp, targ, axis=-1):
    pred,targ = flatten_check(inp.argmax(dim=axis), targ)
    return (pred == targ).float().mean()

def top_5(inp, targ, axis=-1):
    return top_n(5, inp, targ, axis)

def top_10(inp, targ, axis=-1):
    return top_n(10, inp, targ, axis)

def top_n(n, inp, targ, axis=-1):
    _, idx = torch.topk(inp, n)
    return (idx == targ.unsqueeze(axis)).any(axis).float().mean()

def accuracy_tax(tax_targets, inp, targ, axis=-1):
    temp = [torch.argmax(x) for x in inp]
    new_inp = tensor([tax_targets[x.long()] for x in temp])
    new_targ = tensor([tax_targets[x.long()] for x in targ])
    return (new_inp == new_targ).float().mean()    

def accuracy_family(inp, targ, axis=-1):
    return accuracy_tax(family_targets, inp, targ, axis)

def accuracy_genus(inp, targ, axis=-1):
    return accuracy_tax(genus_targets, inp, targ, axis)

# %%
batch_size = 16384
dls = to.dataloaders(bs=batch_size)
len(dls.vocab)
# Out:
# 2957

# %%
learn = tabular_learner(dls)
learn.fine_tune(5)
learn.export("models/v0.3/tabular-f4-no-lat-long.pkl")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_5</th>
#       <th>top_10</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.205503</td>
#       <td>6.178729</td>
#       <td>0.027301</td>
#       <td>0.017342</td>
#       <td>0.030011</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>top_5</th>
#       <th>top_10</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.136428</td>
#       <td>6.136303</td>
#       <td>0.028023</td>
#       <td>0.016973</td>
#       <td>0.030132</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.111842</td>
#       <td>6.113156</td>
#       <td>0.028683</td>
#       <td>0.017123</td>
#       <td>0.029955</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.093467</td>
#       <td>6.096765</td>
#       <td>0.029024</td>
#       <td>0.017238</td>
#       <td>0.030050</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.078681</td>
#       <td>6.085807</td>
#       <td>0.029469</td>
#       <td>0.017157</td>
#       <td>0.029976</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6.070002</td>
#       <td>6.083148</td>
#       <td>0.029582</td>
#       <td>0.017133</td>
#       <td>0.030087</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1727839/639988410.py in <module>
#       1 learn = tabular_learner(dls, metrics=[accuracy, top_5, top_10])
#       2 learn.fine_tune(5)
# ----> 3 learn.export("models/tab/v0.3-tabular-f4-no-lat-long.pkl")
#
# ~/.local/lib/python3.10/site-packages/fastai/learner.py in export(self, fname, pickle_module, pickle_protocol)
#     381         #To avoid the warning that come from PyTorch about model not being checked
#     382         warnings.simplefilter("ignore")
# --> 383         torch.save(self, self.path/fname, pickle_module=pickle_module, pickle_protocol=pickle_protocol)
#     384     self.create_opt()
#     385     if state is not None: self.opt.load_state_dict(state)
#
# /usr/lib/python3/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     375     _check_dill_version(pickle_module)
#     376
# --> 377     with _open_file_like(f, 'wb') as opened_file:
#     378         if _use_new_zipfile_serialization:
#     379             with _open_zipfile_writer(opened_file) as opened_zipfile:
#
# /usr/lib/python3/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     229 def _open_file_like(name_or_buffer, mode):
#     230     if _is_path(name_or_buffer):
# --> 231         return _open_file(name_or_buffer, mode)
#     232     else:
#     233         if 'w' in mode:
#
# /usr/lib/python3/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     210 class _open_file(_opener):
#     211     def __init__(self, name, mode):
# --> 212         super(_open_file, self).__init__(open(name, mode))
#     213
#     214     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/tab/v0.3-tabular-f4-no-lat-long.pkl'

# %%
# preds = learn.get_preds(dl=dls.valid)
row, clas, probs = learn.predict(data.iloc[200035])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
row, clas
# Out:
# (     kg  elu_class1  elu_class2  elu_class3  normalized_month  season  \
#  0  16.0        10.0         5.0         2.0               2.0     4.0
#
#     decimallatitude  decimallongitude  species
#  0         0.110528         -0.217228   1299.0  ,
#  tensor(1299))

# %%
# Out:
# torch.return_types.topk(
# values=tensor([0.0135, 0.0108, 0.0105, 0.0105, 0.0104, 0.0100, 0.0099, 0.0094, 0.0094, 0.0094, 0.0092, 0.0089, 0.0089, 0.0084, 0.0084, 0.0083, 0.0081, 0.0080, 0.0080, 0.0079, 0.0077, 0.0077, 0.0077, 0.0075,
#         0.0075, 0.0074, 0.0072, 0.0071, 0.0071, 0.0071, 0.0070, 0.0069, 0.0069, 0.0067, 0.0066, 0.0066, 0.0065, 0.0065, 0.0063, 0.0062, 0.0062, 0.0062, 0.0061, 0.0061, 0.0061, 0.0061, 0.0060, 0.0060,
#         0.0059, 0.0056, 0.0056, 0.0055, 0.0055, 0.0052, 0.0052, 0.0052, 0.0052, 0.0051, 0.0051, 0.0051, 0.0051, 0.0050, 0.0050, 0.0050, 0.0049, 0.0048, 0.0048, 0.0047, 0.0047, 0.0047, 0.0047, 0.0046,
#         0.0046, 0.0045, 0.0045, 0.0045, 0.0044, 0.0044, 0.0044, 0.0043, 0.0042, 0.0042, 0.0041, 0.0041, 0.0041, 0.0041, 0.0040, 0.0040, 0.0040, 0.0039, 0.0038, 0.0038, 0.0038, 0.0037, 0.0037, 0.0036,
#         0.0036, 0.0036, 0.0035, 0.0035, 0.0034, 0.0034, 0.0033, 0.0033, 0.0033, 0.0032, 0.0032, 0.0032, 0.0032, 0.0031, 0.0030, 0.0030, 0.0030, 0.0030, 0.0030, 0.0030, 0.0030, 0.0029, 0.0029, 0.0028,
#         0.0028, 0.0028, 0.0027, 0.0027, 0.0027, 0.0027, 0.0026, 0.0026, 0.0026, 0.0026, 0.0026, 0.0026, 0.0026, 0.0026, 0.0026, 0.0026, 0.0026, 0.0026, 0.0025, 0.0025, 0.0025, 0.0025, 0.0025, 0.0024,
#         0.0024, 0.0023, 0.0023, 0.0023, 0.0023, 0.0023, 0.0022, 0.0022, 0.0022, 0.0021, 0.0021, 0.0021, 0.0020, 0.0020, 0.0020, 0.0020, 0.0020, 0.0019, 0.0019, 0.0019, 0.0019, 0.0019, 0.0019, 0.0018,
#         0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0018, 0.0017, 0.0017, 0.0017, 0.0017, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0016, 0.0015, 0.0015, 0.0015,
#         0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0013, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0012,
#         0.0012, 0.0012, 0.0012, 0.0012, 0.0012, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0010, 0.0009,
#         0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0009, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008, 0.0008,
#         0.0008, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0007, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0006,
#         0.0006, 0.0006, 0.0006, 0.0006, 0.0006, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0005, 0.0004, 0.0004, 0.0004,
#         0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.0004, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003,
#         0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003, 0.0003,
#         0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002,
#         0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002,
#         0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002, 0.0002,
#         0.0002, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#         0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001,
#         0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001]),
# indices=tensor([1299, 2259, 1672, 2149, 1936,  494, 2414, 1495,  391, 1939,  283,  469,  503,  447, 1493, 2874, 1866,  454,  223, 2632, 1487, 1518,  488, 1935, 1558, 1300, 1853,  456, 2749, 2219, 2217, 2416,
#          350, 2850, 1559,  487, 1674, 1489, 2843, 2233, 2617,  455,  458,  922, 2575,  466,  467,  453, 1888, 1819, 2364, 2711, 1517, 1867,  476, 2216,  498, 1704, 1555, 2745, 1813, 2616,  471,  843,
#         1556,  961,  394, 1974, 1116,  980, 1500, 2923, 2120,  230, 2126, 1868, 1515,  171,  835, 2146,  500,  193, 1042, 2229,  620, 1520, 2033, 1971,  486,  448, 2853,   60, 2878, 1676,  346, 2118,
